# %%
import import_ipynb
import Location
from Location import *
from Enum_profile import *
from Profile import *
import Data
from Data import *
import Operation
from Operation import *
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
# Out:
# importing Jupyter notebook from Location.ipynb
# importing Jupyter notebook from Enum_profile.ipynb
# importing Jupyter notebook from Profile.ipynb
# importing Jupyter notebook from Data.ipynb
# importing Jupyter notebook from Operation.ipynb

# %%
user1 = Localisation( "France", "Southeast")
p = Foyer("EDF", user1,"Actif", 2, "profil_foyer")      
calcul = Calculation(0.157,6,p)  

def main():
    print('Here are the expected results : ')

if __name__ == "__main__":
    main()
cout_sale = 0.08 
production_price = 0.1
injection_price = 0.09
subscription = 120

print(calcul.resultat_profil_B(cout_sale, subscription, production_price,injection_price))
# Out:
# Here are the expected results :
# time
# 2020-01-01 00:00:00   -0.6450
# 2020-01-01 01:00:00   -0.5475
# 2020-01-01 02:00:00   -0.4500
# 2020-01-01 03:00:00   -0.4500
# 2020-01-01 04:00:00   -0.4500
#                         ...
# 2020-12-31 19:00:00   -1.6950
# 2020-12-31 20:00:00   -1.0500
# 2020-12-31 21:00:00   -1.3950
# 2020-12-31 22:00:00   -0.9525
# 2020-12-31 23:00:00   -0.9000
# Name: difference, Length: 8784, dtype: float64
# total consumption :  9335.894999999944
#   the customer's bill :  328.342610622149
#  the sale is:  579.5632633772444
#  the total Pv production is:  7244.5407922155555
#  energy_value for total sale -593.2334264664602
#  energy_value for injection is  -448.342610622149
# None
